# %% [markdown]
# <a href="https://colab.research.google.com/github/007-athul/DSA-case-study1/blob/main/pandas_activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Load the Titanic dataset and display the first 10 rows.

# %%
import pandas as pd
df = pd.read_csv("titanic_dataset.csv")
print(df.head(10))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#2. Find the number of missing values in each column.

print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#3. Find the percentage of passengers who survived, grouped by gender.

survival_percentage = df.groupby('Sex')['Survived'].mean() * 100
print(survival_percentage)
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
#4. Find the average, median, and standard deviation of passenger ages.

print("Average Age:", df['Age'].mean())
print("Median Age:", df['Age'].median())
print("Standard Deviation:", df['Age'].std())
# Out:
# Average Age: 29.69911764705882
# Median Age: 28.0
# Standard Deviation: 14.526497332334044

# %%
#5. Count how many passengers were in each class (Pclass).


print(df['Pclass'].value_counts())
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
#6.Show all passengers who were female, under age 18, and survived.

result = df[
    (df['Sex'] == 'female') &
    (df['Age'] < 18) &
    (df['Survived'] == 1)
]

print(result)
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 10            11         1       3
# 22            23         1       3
# 39            40         1       3
# 43            44         1       2
# 58            59         1       2
# 68            69         1       3
# 84            85         1       2
# 156          157         1       3
# 172          173         1       3
# 184          185         1       3
# 208          209         1       3
# 233          234         1       3
# 237          238         1       2
# 307          308         1       1
# 329          330         1       1
# 381          382         1       3
# 389          390         1       2
# 435          436         1       1
# 446          447         1       2
# 448          449         1       3
# 469          470         1       3
# 479          480         1       3
# 504          505         1       1
# 530          531         1       2
# ...

# %%
#7. Replace missing age values with the median age.

median_age = df['Age'].median()
df['Age'] = df['Age'].fillna(median_age)
print(df['Age'])
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
#8. Create a column age_group with values:
# Child for age < 18
# Adult for age 18–60
# Senior for age > 60

def age_group(age):
    if age < 18:
        return "Child"
    elif age <= 60:
        return "Adult"
    else:
        return "Senior"

df['age_group'] = df['Age'].apply(age_group)
print(df[['Age', 'age_group']])
# Out:
#       Age age_group
# 0    22.0     Adult
# 1    38.0     Adult
# 2    26.0     Adult
# 3    35.0     Adult
# 4    35.0     Adult
# ..    ...       ...
# 886  27.0     Adult
# 887  19.0     Adult
# 888  28.0     Adult
# 889  26.0     Adult
# 890  32.0     Adult
#
# [891 rows x 2 columns]

# %%
# 9. Display the top 5 passengers who paid the highest fare.

print(df.nlargest(5, 'Fare'))
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
# 27            28         0       1      Fortune, Mr. Charles Alexander
# 88            89         1       1          Fortune, Miss. Mabel Helen
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 27     male  19.0      3      2     19950  263.0000  C23 C25 C27        S
# 88   female  23.0      3      2     19950  263.0000  C23 C25 C27        S
#
#     age_group
# 258     Adult
# 679     Adult
# 737     Adult
# 27      Adult
# 88      Adult

# %%
# 10. Find the average fare paid, grouped by both Pclass and Sex.
avg_fare = df.groupby(['Pclass', 'Sex'])['Fare'].mean()
print(avg_fare)
# Out:
# Pclass  Sex
# 1       female    106.125798
#         male       67.226127
# 2       female     21.970121
#         male       19.741782
# 3       female     16.118810
#         male       12.661633
# Name: Fare, dtype: float64

# %%
# 11. Rename the following columns:
# 'Sex' → 'Gender'
# 'Fare' → 'Ticket_Fare'

df.rename(
    columns={
        'Sex': 'Gender',
        'Fare': 'Ticket_Fare'
    },
    inplace=True
)
print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket  Ticket_Fare Cabin Embarked age_group
# 0      0         A/5 21171       7.2500   NaN        S     Adult
# 1      0          PC 17599      71.2833   C85        C     Adult
# 2      0  STON/O2. 3101282       7.9250   NaN        S     Adult
# ...

# %%
# 12. Count the number of passengers who survived and didn't survive, grouped by class.

result = df.groupby(['Pclass', 'Survived']).size()
print(result)
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# dtype: int64

# %%
# 13. Find the average age of passengers grouped by both class and gender.

avg_age = df.groupby(['Pclass', 'Gender'])['Age'].mean()
print(avg_age)
# Out:
# Pclass  Gender
# 1       female    33.978723
#         male      38.995246
# 2       female    28.703947
#         male      30.512315
# 3       female    23.572917
#         male      26.911873
# Name: Age, dtype: float64
